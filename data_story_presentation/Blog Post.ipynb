# %% [markdown]
# ## A Total Guide to Fantasy Football: Patterns, Projections, and More:
#             The ins-and-outs of the game, how it is played, & how to succeed.

# %% [markdown]
# ![]("https://wallpapercave.com/wp/AXBJdYd.jpg")
# <img src ="https://wallpapercave.com/wp/AXBJdYd.jpg" width=600 />

# %% [markdown]
# ### What is Fantasy Football?
#
# Fantasy Football is a game in which a group of people, traditionally around 10 people per fantasy league, act as 'general managers' or 'owners' of their own National Football League Team. They draft 15 players, ranging all positions (as listed below), in a 15 Round  draft (like that in which collegiate players are drafting into the NFL-National Football League each year). All NFL players are available for selection and it is up to the 'general manager'/ the person drafting to select who they want on their team. This is very much a draft of strategy. Everyone has different strategy but there is a general scheme that should be loosely followed.
#
# The positions are:
# - QB = Quarterback
# - RB = Running back
# - WR = Wide Receiver
# - TE = Tight End
# - FLEX = a position in fantasy line-up where you can put an extra WR, RB, or TE
# - K = Kicker
# - D/ST = Defense/Special Teams
#
# With this basic understanding of fantasy football I conducted a series of analysis through 13 main data frames (10 of which came from the same source). I first started with 10 Top-50 lists from the years 2010 to 2019. What this told me was the Top-50 NFL players who generated the most points in the regular season of that year. I created a conjoined list of all 10 of these data frames and made it into 1 to conduct further analysis and compare each of the past 10 seasons of fantasy football (the statistics). I then created a separate data frame containing just the Top-10 players from each year. I found patterns amongst the the Top-50 and the Top-10 including players that re-appeared on these lists multiple year spanning 2010-2019 and also positional breakdowns of each list. I then went on to create a third data frame in which I analyzed just the Top player, the #1 ranked fantasy player, for each year. I did an in-depth comparison on these 10 players.
#
# I also looked at 3 more data frames to see if fantasy rake had any correlation with 3 different areas of the NFL. One being the League MVP award. Second was the SuperBowl champions and runner-ups. And, third was the Top-20 average salaries in the NFL (2020 salaries).
#
# I will begin to breakdown the story I found, on how to pick your fantasy team for success, and how to trust the stats... are breakout players a one season and done or are they breakthrough players for the remainder of their career. So what is worth the risk?
#
# I hope this story can give all those Fantasy Football lovers an insight into what truly comprises the Top Fantasy Players.. what to take your shot at ... and also what to avoid.
#
# ENJOY!

# %% [markdown]
# ### Where the story all begins...

# %% [markdown]
# #### Lets take a look at the Top-50 charts for years 2010-2019:
#
# The guidelines to make this list are to be a Top-50 fantasy football point scorer over the course of the regular season. There are various statistics that comprise who makes it into the Top-50. Meaning, how can each position "generate points".

# %% [markdown]
# |How QBs generate points            | How WR's generate points| How RBs generate points |
# | ----------------------------------|-------------------------| ------------------------ |
# |  yards thrown                    | receptions             | rushing yards           |
# |  TDs thrown              |reception yards        | rushing TDs      |
# | negative points for interceptions thrown | TDs     | receptions              |
# |  rushing yards                   |                         | reception yards         |
# |  rushing TDs           |                         | reception TDs    |

# %% [markdown]
# |How TEs generate points| How K's generate points| How D/ST generate points|
# |-----------------------|------------------------|-------------------------|
# |  reception            |extra points            |sacks
# | reception yards       |field goals             |fumbles forced, fumbles recovered
# | TDs                   |negative points for missed kicks|negative for points/TDs/yards allowed|

# %% [markdown]
# KEY TERMS:
# - TD = Touchdown
# - reception = caught pass
# - reception TD = touchdown caught
# - rushing yards = yards run
# - rushing TD = running touchdown

# %% [markdown]
# ### The past 10 years...

# %% [markdown]
# Over the past 10 years we can see the point curve is generally, for the most part, trending upward. From 2010-2016 it was very up and down, one year the max points scored would be very high and the next it would drop a little. Since 2017 it has remained relatively high and actually has reached its highest in 2018. Both 2018 and 2019 had maximum total points values in the 400's (this is A LOT if points to be scored)!

# %% [markdown]
# ![download-1.png](attachment:download-1.png)

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# I became interested as to which year would it have been the easiest as a player to crack into the Top-50. Meaning, what were the comparisons of average points needed to gain a spot on this prestigious list. As shown in the graph below, the highest average was most definitely 2018. In 2018, the average number to be in the Top-50 was 245.58 compared to the next closest year, 2019 which was only 239.31.
#
# What I can tell from this is that in 2018 it was hardest for NFL players to break into the Top-50. What I can also tell is that we are seeing another upward trend. Players are recording more fantasy points and I predict we will continue to see this in years to come. Get ready for some HUGE numbers to be put up on the scoreboard in your fantasy match-ups in the years to come.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# **** This graph is representing only the maximum total points scored by one player in the year listed.

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# ### So.. the question becomes.. which position scores the most fantasy points?

# %%
#bar chart of positional breakdown of the top50
# 5 bars per year, 10 years

# %% [markdown]
# These 4 players are the only 4 that have made an appearance in all 10 of the Top-50 lists.
# Top left is Matt Ryan, quarterback of the Atlanta Falcons. Top Right is Tom Brady, former quarterback of the NE Patriots and current quarterback of the TB Buccaneers. Bottom Left is Philip Rivers, quarterback of the LA Chargers. And bottom right is Drew Brees, quarterback of the NO Saints.
#
# The most important thing to identify is that all 4 of these players play the same position. They are all quarterbacks. Despite being the most reoccurring players in the Top-50 charts, they are not always the #1 ranked fantasy player or even in the Top-10. Out of the 4 the only 1 to have held the #1 spot is Drew Brees. He did so in 2012 when he totaled 345.58 points on the season. On top of holding the #1 rank, Drew Brees also appeared within the Top-10 on 9 occasions. The only year he was not in the Top-10 was last year, 2019.
#
# Matt Ryan has appeared in the Top-10 6 times. His highest rank has been the #2 spot which he held in both 2016 and 2018.
#
# Tom Brady has appeared in the Top-10 5 times. His highest rank also was the #2 position which he held in 2015.
#
# Philip Rivers has only appeared in the Top-10 3 years. His highest rank was #6 spot which he achieved in 2010

# %% [markdown]
# <tr>
# <td> <img src="https://cdn.cnn.com/cnnnext/dam/assets/130110193804-falcons-01-horizontal-large-gallery.jpg" alt="Drawing" style="width: 300px;"/> </td>
# <td> <img src="https://www.si.com/.image/ar_4:3%2Cc_fill%2Ccs_srgb%2Cfl_progressive%2Cq_auto:good%2Cw_1200/MTY5NTI0Mzg2NjY2MTI4Njcz/tom-brady-patriots-titans-nfl-wild-card-playoffs.jpg"" alt="Drawing" style="width: 300px;"/> </td>
# </tr>
# <td> <img src="https://i1.wp.com/www.nflanalysis.net/wp-content/uploads/2020/02/philip-rivers.jpg?fit=1000%2C600&ssl=1" alt="Drawing" style="width: 300px;"/> </td>
# <td> <img src="https://d.newsweek.com/en/full/1527120/drew-brees.jpg" alt="Drawing" style="width: 300px;"/> </td>
# </tr>

# %% [markdown]
# The Quarterback consistently is coming out "on-top". Here you will see a positional breakdown of the combined Top-50 lists over the past 10 years. 500 players in total in this combined data frame.

# %%
#insert bar graph of positional breakdown of the top-50

# %% [markdown]
# ![download-2.png](attachment:download-2.png)

# %% [markdown]
#          Number of each position in the Top-50 for the past 10 years

# %% [markdown]
# |QB           | RB              | WR          | TE           |  K           | DST          |
# |-----         |-----           |-------       |----         |-----          |------        |
# |235|   120  | 84   | 6   | 2   | 20   |

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# ### Now a look into the Top-10:
# In the past 10 years only 2 positions have had the ability to rack up enough points to make it into the Top-10 of players. Those two positions are QB and RB. QB, again, is by a large margin the most notable position in the top-10 of the fantasy ranks. As I will go into now.. being the #1 rank/in the top-10 of the fantasy ranks has a strong correlation to League MVP recipient and highest average salaries (as of 2020) BUT... DOES NOT correlate with being a member of a SuperBowl contender and most notably the positional breakdown of these ranks DOES NOT correlate with the round in which the position is selected. As i've learned and will teach you through this story.. there is a lot more that goes into a fantasy draft than the fact that QB's generate the most points. This DOES NOT mean they should be drafted in the first round and I will explain why in the next section.

# %% [markdown]
# ![download-3.png](attachment:download-3.png)

# %% [markdown]
# |QB           | RB              | WR          | TE           |  K           | DST          |
# |-----         |-----           |-------       |----         |-----          |------        |
# |87     |  13   | 0  | 0   | 0   | 0   |

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# ### Lastly, a look into the #1 ranked fantasy players:
#
#
# Over the past 10 years only 2 positions have held this #1 fantasy player spot, Quarterback and Running back. BUT, 9 out of the past 10 years this spot has been secured by a quarterback.
#
# In the past 10 years there is only one player who has stood in this spot, at the end of the regular season, more than once. That is, Green Bay Packers Quarterback, Aaron Rodgers. Not only has he done it more than once, he has done it a total of 3 times in the past 10 years.

# %% [markdown]
# #### A look into the League's past 10 MVPs:
#
# ![]("https://i0.wp.com/bargainbunch.com/wp-content/uploads/2020/07/2020-NFL-MVP-Predictions.png?fit=653%2C528&ssl=1")
# <img src ="https://i0.wp.com/bargainbunch.com/wp-content/uploads/2020/07/2020-NFL-MVP-Predictions.png?fit=653%2C528&ssl=1" width=300 />
#
# In the past 10 years, 6 times it has aligned that the League MVP is also the #1 ranked fantasy football player of the season. All 6 times, this player was a Quarterback. Although it is not a guarantee that the #1 ranked fantasy player also wins MVP, it is likely and common (it happens slightly over 50% of the time).
#
#
# Also substantial about the League MVP data is that 9 out of the past 10 have also been awarded to QB's. Through all of this analysis so far it is obvious that the most important, rewarding, and point generating position on the field is without a doubt, the Quarterback. Still..remember... for reasons we will go into later, you should not select a quarterback for your team in the first few rounds of the draft.
#
# You have to proceed with caution here.. as in rare but SOME cases the League MVP recipient might not even be one of the Top-10 point generators. Something to consider upon ranking this MVP high on the draft board for your roster.. there may be some better options. Meaning, for example, in 2017 Russell Wilson (QB) had the most amount of fantasy points BUT Tom Brady was awarded League MVP. Yes.. Tom Brady is a phenomenal player and if you are a fan of his team you are a HAPPY person most game days BUT.. that does not mean he is the QB that is going to generate the most amount of points for your fantasy team. In this particular year, Russell Wilson was the better pick.

# %% [markdown]
# #### Quarterbacks:
# It is glaringly obvious that, by a VERY wide margin, quarterbacks are the biggest point generators in the league. In the past 10 years they have continuously dominated the Top-50, the Top-10, and in all years but 1 they have also dominated the number 1 rank. But...it is interesting to see what else this correlates with.

# %%
# think about re-ordering this (weird placing)

# %% [markdown]
# ### The Man, The Myth, The Legend
#
#
# <tr>
# <td> <img src="https://static.clubs.nfl.com/image/private/t_editorial_landscape_12_desktop/packers/l5mkg10ygmadxjbf1s7y.jpg" alt="Drawing" style="width: 250px;"/> </td>
# <td> <img
# src="https://www.cbssports.com/images/blogs/aaron-rodgers-mvp15-honors.jpg"" alt="Drawing" style="width: 250px;"/> </td>
# </tr>

# %% [markdown]
# Who is this guy you might ask. This is Aaron Rodgers. Not only has he been the only repeated fantasy football #1 ranked player over the past 10 years, but he has done so 3 times. In 2011, 2014, and 2016, Aaron Rodgers stood at the Top of the list for points in the regular season. He is also one of only 2 players to have won league MVP multiple times within the past 10 years. Him and fellow quarterback, Tom Brady, have both won the prestigious honor twice since 2010.
#
# THIS is the guy you want on your team.
#
# Maybe worth it to draft a QB earlier than you should if it means getting this absolute legend of a fantasy player and point generator leading the rest of your roster.
#
# But how early in the draft is too early to take that risk on drafting a QB? That is something I will lay out below.

# %%
# add stuff in about how many points he's scored and the .describe() function

# %% [markdown]
# ### Diving into the numbers: Players salaries and more

# %% [markdown]
# Does the top ranked fantasy players and top average salaries correlate with each other. This is interesting. As my fantasy football story has panned out it is evident that quarterbacks are most frequently the #1 fantasy football players each season. It also happens to be that the Top-20 salaries for NFL players (as of 2020) contains 17 QB's.
#
# So.. not only are quarterbacks the most likely to score the most fantasy points each year, this also correlates with player salaries. 6 out of the 10 #1 ranked fantasy players also have one of the top salaries in the NFL. Again player salary is completely dominated by the Quarterback position.
#
# Although a Quarterback often holds the #1 player rank for fantasy football each season AND is among one of the highest paid players in the League...a quarterback is often not your 1st, 2nd, or even 3rd pick in a fantasy draft. It is important to note that although they are not the first pick in the draft, they are the single most important player and biggest point generator on your fantasy team.

# %% [markdown]
# ![download-6.png](attachment:download-6.png)

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# Top-20 salaries in 2020 consists of 17 Quarterbacks, 2 Defensive Ends (which isn't its own position in fantasy so you would draft the defensive unit as a whole, not just them as an individual player) and 1 WR.

# %% [markdown]
# Patrick Mahomes, Quarterback of the KC Cheifs, was the #1 ranked player AND MVP in 2019 and has the highest average salary in the league in 2020. Deshaun Watson and Russell Wilson also have 2 of the highest salaries in the league and happen to be very big point generators for fantasy football.
#
# Takeaway: Look at salary on a positinoal basis. The highest paying players within each position are going to be the best at what they do. It is potentially unhelpful in drafting your team to only look at the Top salaries amongst all players because Quarterbacks are by far the highest paid players in the league. Looking into a salary breakdown by position can really help you find who your target draft picks should be.

# %%
# graph of player slaries and posistions/player salaries and top 10 ranks

# %% [markdown]
# ### Teams that dominate:
# Are there specific teams you should look to when drafting players onto your fantasy team?
#
# There are only 5 teams with 20 or more players in the Top-50 fantasy ranks over the past 10 years. These teams are:
#  - Pittsburgh Steelers (27 appearances)
#  - New England Patriots (22 appearances)
#  - Atlanta Falcons (22 appearances)
#  - Kansas City Chiefs (21 appearances)
#  - Denver Broncos (20 appearances)
#
# One strategy would be to look at these teams and see who their best players are at each position. It is clear that they have a good track record with putting up names in that leader board for points so its not a bad strategy. One that I believe is often overlooked.

# %% [markdown]
# #### "HOT" Teams in the Fantasy Game:

# %% [markdown]
# <tr>
#     <td> <img src="https://images.homedepot-static.com/productImages/e0adcb50-e1ca-4a74-9507-36750e1c8ec7/svn/fanmats-other-exterior-auto-accessories-22602-64_1000.jpg" alt="Drawing" style="width: 200px;"/> </td>
#     <td> <img src="https://lh3.googleusercontent.com/proxy/FjOYDgNbxP84HvAZjzPQT8pQ2g-9qDXXfJfuyd3DJM_uvXF95hJk3abhMV0UHj9jsI_z6-RCyGuZjQZcxVZQxJNABqVA-ntqFxJoR2SH-PK2REFr5y2SkecAkCY2-Y5wjGdg8Zo" alt="Drawing" style="width: 200px;"/> </td>
#     </tr>

# %% [markdown]
#
# <tr>
# <td> <img src="https://lh3.googleusercontent.com/proxy/rmM2YccXelWeva3ahNj4fM75PeOTYKO3s-uqNuVVDtxg5xLZjeYfjx1GL1ATg7ildU5n0RYDhTxgWauEk3gX9zvb3zOhgv5LxDOFCPxV3SGbwEXyA1RAdhoMepDrHR3l" alt="Drawing" style="width: 200px;"/> </td>
# <td> <img src="https://i.pinimg.com/originals/cd/c7/d2/cdc7d22bae09c87afc3e6d333dbfe265.jpg" alt="Drawing" style="width: 200px;"/> </td>
# </tr><tr>
# <td> <img src="https://lh3.googleusercontent.com/proxy/QXyYr-CzR5CoDStwgPOuIgU8itNJF9JFQkClsFS67swwts-WqJ46Kv9edxfMWjMGL72wkl3N6PDLgfeW1yjj8R7py2K4O65aW8yb_lDH1qQ6CXhFuLfHGgue-Vh_KhDRd7OlachYtA" alt="Drawing" style="width: 200px;"/> </td>
#     </tr>

# %% [markdown]
# ### Professional Draft Tips:
# * What do the NFL professionals say about how you should draft your fantasy team?
# * How does my analysis align with this and how is it able to explain this?

# %% [markdown]
# #### First lets lay-out the fantasy football line-up:
#     1 Quarterback (QB)
#     2 Running Backs (RB)
#     2 Wide Receivers (WR)
#     1 Flex (choose from RB/WR/TEs)
#     1 Tight End (TE)
#     1 Placekicker (K)
#     1 Team Defense/Special Teams (D/ST)
#
# - there are also 6 Bench (BN) players. The players in your bench DO NOT count for the points total of your team during your match-up.

# %% [markdown]
# #### According to NFL Professionals, this is how they suggest you should draft your fantasy team for success:
#
# #### TIP #1: In Round 1 you should draft a RB
#    This was interesting because if you are going based off of who generates the most amount of points for your team it should be obvious that you should pick a Quarterback. But heres the thing, there are 9 to 10 quarterbacks each year that make it into the Top-10 of the ranks (with the range of point totals not being very drastic). There are typically only 10 teams per league. That being said, although you might not get the best quarterback by waiting till a much later round, there is a very good change of you drafting a quarterback that is still a top-10 or top-20 point generator. Good, point generating QB's aren't scare. BUT.. RB's are for a number of reasons. And, it is so important to draft at least 1 really good one because you need 2 in your line-up each week. Problem #1 with running backs is that they do not play every play and often teams rotate between 2 or 3 of them. If you can find a team that has a distinct and set running back that they go to all the time, you need to get them early. Second problem is there is a huge drop-off with RB's. There are a few that make the top charts, but only a few. If you wait too long to get a running back, you're going to be stuck with ones who simply do not generate enough points for you to succeed. So.. tip #1 is... get a good/go to running back AND draft them EARLY.
#
# #### TIP #2: In Round 2 you should draft a WR.
#    Wide receiver similar to RB except not as important because  typically RBs generate more total points. But you need 2 of them in your lineup and there is also a pretty big drop-off in total points between the 10-15 best in the league and the rest. There are not enough really big point generating WR's for each team to have 2 of them. Again, like RBs there are multiple strings of WRs, you want to make sure you are able to draft at least 2 first string WRs that are high point generating. If you wait too long to draft a WR you might get stuck with a player that is not their teams "go-to" guy and therefore they don't get as many reps in the games and will therefore not generate many points. Only 5 wide receivers made it into the Top-20 in any of the past 10 years (as shown in the graph below). This emphasizes the importance of getting at lest one good WR because there are a few good ones and then there is a drop off.
#
# #### TIP #3: Round 3-6 you should aim to draft either a RB or WR (make sure you are picking even #'s of each):
#    Get them early. Get at least 2 really good "go-to" first string players. They go fast and you need to get them while they can. The drop-off of these positions is much higher than that of Quarterbacks
#
# #### TIP #4: Round 7 draft a TE
#    TEs are often not some of the bigger point scorers. I would describe them as they background player. They don't appear frequently in the Top of the ranks. You only need to play 1 of them in your line-up so its not essential to focus on getting more than 1 reallyy good one. As shown in the graphs above and below, only 1 TEs, over the past 10 years, has appeared even in the Top-20 fantasy player ranks. They are not going to generate a ton of points like the RBs and WRs but it is important to draft at least 1 first string TE being they get substantially more plays and reps in the game than 2nd and 3rd string TEs.
#
# #### TIP #5: Around Round 8-9 you want to draft a QB
#    If you wait past round 8 to draft a QB that just means you most likely will not get the best, top-tier, high- caliber QBs that are often round in the top 5 spots of the ranks. Many of the really good quarterbacks will be around during round 8... although there is a chance someone snags the #1 slightly earlier.
#
# #### TIP #6: Rounds 9-12 is more about drafting the best available player at either the QB, WR, RB, or TE position
#    These players are most likely going to be on your bench so it is not super important. It is important to draft the best player available that is one of these positions that it projected to generate the most points. My biggest piece of advice here is look to last years statistics to determine which player is the better choice. There is not much discrepancy in Top players. Meaning, if they are in the Top-50 one year, it is likely they will generate  decent amount of points the next year as well. This is an opportunity to get the best available bench players possible. These players will most likely remain on your bench unless one of your starters get injured, one of your starters has a bye week, or a bench player is simply having a breakout season and was a great pick late on in the draft (exceeded expectations).
#
# #### TIP #7: Round 13 draft a kicker.
#    Kicker's often don't generate many points and there are a lot of them who are about equal with the exception of the 1-2 kickers who are just exceptional. That being said they don't play much and often do not get the opportunity to generate a great deal of points. Throughout the past 10 years, there has only been 2 occassions in which a Kicker appeared in the Top-50 (they never appeared in the Top-10 or Top-20) and the highest rank a Kicker has held is #40.
#
# #### Tip #8: Round 14-15 draft a Defense/Special Teams (D/ST) or K.
#    Defense's are very up-and-down on a point generating term completely depending on who they are playing. When they are playing a poor offensive team, many D/ST rack up points, but on a week where they are playing a well oiled offense, they often will only generate a few points (sometimes they will generate '0' or even a negative number). It is ideal to get one of the top-5 ranked Defenses but this is a position that is going to be available still at the very end of the draft.

# %% [markdown]
# ![download-5.png](attachment:download-5.png)

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# This graph emphasizes the plethora of "good", "high point scoring" QBs that are available to draft. The thing is there are more really good quarterbacks available to draft than there are teams in the draft. That means some teams will get more than 1 quarterback that is a top-20 point scorer. Whereas for running backs only half the teams in the league will even get 1 RB that is a top-20 point scorer. Theres few really, really high scoring RBs and you want to draft them before they're gone.

# %% [markdown]
# ### The Complete Breakdown and Explanation to it All:

# %% [markdown]
# ![download-7.png](attachment:download-7.png)

# %% [markdown]
# the data represented in this graph is from:

# %% [markdown]
# This is the graph that says it all. It is a breakdown of the average total points of each position over the past 10 years vs. how many players of that position are listed as a Top-50 fantasy point scorer.
#
# Quarterbacks are the Kings of the game. They score the most points, the win the most MVP awards, and they make the most money. So...my question this whole time is why wouldn't you pick a QB in the first round if they have completely dominated the fantasy football ranks for the past 10 years. The answer is in this graph here itself..Yes, quarterbacks generate the most amount of total points each year BUT they are also the position with the most amount of players in the Top-50. They're a hot commodity but there is a high supply (just like the supply-and-demand chain). So, don't waste your number 1st, 2nd, or 3rd draft pick on these guys because even if someone else in the league does, theres enough high-caliber quarterbacks in the league that you are almost guaranteed to end up with one.
#
# Running backs. Why should they be selected by all league 'general managers' Round 1? As depicted in the graph above, the Running Back position is the second highest point generating position in the league. The big thing to take into account here is that there are only half as many RB's that generate enough points to make the Top-50 cut-off than there are quarterbacks. They are also of high demand not only because they generate a decent amount of points but also because you need 2 of them in your starting line-up. Very high demand with a slightly low availability. This is why you have to get the best possible RB that you can in the first round.
#
# Drafting a wide receiver early has a similar reasoning behind it. They don't generate as many points as a RB, but there are also few WR's who appear in the Top-50 of the ranks. It is important that you get one of them early because, like RB's.. 2 WR's start in your line-up. It is essential to score at least 1 of the top WRs in order for your team to succeed. To do this, you need to draft them early or another 'general manager' will beat you to it.
#
# TE, K's, and D/ST. All very low supply in the top-50 ranks over the past 10 years. They're not the biggest point generator on any single fantasy team and you only need one of each in your line-up. Don't make this your focus but also don't push off getting a TE until the very last round. You want to make sure you pick at least 1 TE who is their specific NFL teams' first string or else your TE will not get sufficient even plays in the game to impact your team enough to succeed. With K's and DST you usually only select one per team and there are plenty first strings to go around. Definitely save these for your last 2-3 picks (there aren't many in the top of the ranks and if they even did make the top-50 they made the very tail end of it).
#
# I can't promise you will come in first place but if you follow this total guide to fantasy football I can assure you, you are doing it right. Pick smart, do your research, and take some risks on certain players (they might surprise you and be the difference maker).

# %% [markdown]
# ### Last thing, a subtle reminder, where to look for the trends to help draft your team:
# Here is a list of my tips on where to look to find trends to help you select the best team possible.
#
# #1: Look to the Top-50 fantasy lists from the previous years...if a player is on multiple...take a risk he is probably going to be on it again (although I wouldn't consider that much of a risk!)
#
# #2: Look to average salaries. On a positional basis, which players are being paid the most. The more the player is paid (not 100% of the time but MOST of the time) the more fantasy points they generate. Although it is not an intended correlation because that is not what NFL teams look at (fantasy points) when they give a player a contract but it is no coincidence that the best players in the league are getting paid the most AND consistently total some of the most fantasy points in the League.
#
# #3: SuperBowl contenders does not correlate with top fantasy players. I WOULD NOT recommend specifically looking at just players who were on a SuperBowl contending team the year before. There is no evidence that proves that these SuperBowl teams are the ones with players putting up a high fantasy points total. But... don't get me wrong, there are some instances where the shining star of the fantasy football league is also the SuperBowl MVP (like Patrick Mahomes in 2019 -- he did it all).
#
# #4: There are a few teams who have had more players appear in the Top-50 over the past 10 years than others. But, this isn't extremely reliable as it can change year-by-year and it is really dependent on the player themself and what they are capable of producing on the field. It is important to keep in mind that the better teams in the NFL are going to have better chances of producing more points. For example, picking a WR on a team with an awful quarterback is not smart because although that WR is able to make a play the QB is terrible at getting him the ball.. therefore he is not going to generate the points that you need. The team the player plays for is by no means the most important factor to consider when drafting your team BUT.. it is something that should not be overlooked and can help you get the upperhand in some cases.
#
# #5: When thinking about your draft order REMEMBER...It all comes down to supply and demand. Strategize when selected when you want to draft who because remember these few key things I've learned through developing this story:
#     * QB's are the most point generating players but there are enough really high point generating QB's to go around (the drop off of the top-10 QB's is not substancial and there are only 10 teams in each fantasy league). Although drafting the #1 QB is ideal, it is not going to make or break your team.
#
#     * Draft a RB early. They are high point generators but there are only a few really notable RB's that will drastically impact your team. Get one of them and you are destined to succeed. There are not enough really high point scoring RB's for each team in the league to draft 2 of them...some teams will be left with back-ups if they don't draft them early.
#
#     * Draft Kicker & Defense last
#
#     * Focus on the positions that are most prevelant in your lineup: 2 RB's and 2 WR's in each line-up

# %%
# create links for where your data has come from under each of the sections (specifically for the charts)
- information received from "x" url

# %%
# insert graphics

# %%
# where got data from -- list of citations

# %%
# go into the top 5 tips/strategies to picking the best fantasy team possible

# %%
# go through the salaries 
# go through the superbowl contender appearances 
# go through the draft recommendations
# your analysis/ conclusions on the recommendations and layout to succeed in fantasy football (what is worth the risk etc.)

# %% [markdown]
# ### What does this mean in terms of when I should draft these players:

# %% [markdown]
# *** just notes on what to add***
#
# ## A few things to consider...
# ---- this is where you go into explanation about why you wait to select a qB and why you have to hop on RB early ----
# - RBs dont play every snap, only 1 on field at once and 2 are in your fantasy lineup
# - WR is pretty much right there as they play multiple strings so it is really important you get at least 1 1st string and you need 2 in your lineup
# - QB -- there are enough good ones that every person in the league (being there are only 10 in the league) will have the opprotunity to pick a hguh point generating QB

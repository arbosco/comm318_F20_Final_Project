# %% [markdown]
# ## What this notebook will do/consist of:
# - In this notebook I am going to import all of my data
# - This will consist of Fantasy Football Statistics from dating back 10 years
#     - from 2010-2019 season (I will not include 2020 because it is not complete yet so the numbers would be on a different scale then the rest of the data sets therefore it would only be a projection).
# - First I will load in all of the functions necessary to scrape these web-pages.
# - My second step will be pulling tables from various pages of the website url: "https://fantasydata.com/nfl/fantasy-football-leaders?season=2010&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1"

# %% [markdown]
# # Step 1: Set Up Functions:

# %%
import os
import json

from collections import Counter

# %% [markdown]
# ## Step 2: Importing and reading the 10 url's into this notebook:
# * all are from the same web page: ""https://fantasydata.com/nfl/fantasy-football-leaders?season=2010&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1"

# %%
fantasy_football_statistics = {
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2010&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2011&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2012&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2013&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2014&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2014&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2015&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2016&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2017&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2018&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1',
    'url' : 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2019&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1'
}

# %%
# explain using markdown cell what you are doing in the below cells 
# explain the pointers & what each one is representing

# %% [markdown]
# # Step 3: Assigning a pointer:
# * In this step I assigned a pointer to each one of the URL's imported in 'Step 2'
# * Each pointer references one .csv file
# * Each .csv file is 1 year worth of data/statistics
# * Each pointer contains the year that the data it is pointed to is from

# %%
fantasystats_2010 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2010&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2011 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2011&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2012 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2012&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2013 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2013&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2014 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2014&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2015 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2015&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2016 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2016&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2017 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2017&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2018 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2018&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
fantasystats_2019 = pd.read_html('https://fantasydata.com/nfl/fantasy-football-leaders?season=2019&seasontype=1&scope=1&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=1')

# %%
#  create a markdown stating the next step in this process of converting tables to csv file

# %% [markdown]
# # Explanation: How I derived  .csv files from the URL's above
#
# * I was unable to download the tables from 'fantasydata.com' so I had to manually do it.
# * Steps to create .csv files:
#     * Step 1: I individually went to each of the 10 URL's listed above (1 by 1).
#     * Step 2: I copied the table that I wanted from the year I was analyzing (for example, I went to the 2010 fantasy stats page and copied the 'regular season' top 50 players stats and copied it to my clipboard)
#     * Step 3: I then created an excel and formatted the row headings and column headings to replicate that of the website.
#     * Step 4: Next I pasted the statistics into the excel sheet
#     * Step 5: Lastly I saved it as a .csv file and was then able to upload it into jupyter

# %%
fantasystats_2010_df = pd.read_csv("../data/fantasystats_2010.csv", skiprows=1, nrows=50)

# %% [markdown]
# - **as denoted by the 'skiprows=1, nrows=50' in the code above I am skipping the first row to unnecessary row in each of the tables. So the total number of rows I want in each table is 50 (nrows =50)

# %%
fantasystats_2010_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2010_df
# Out:
#     RK                   NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1           Arian Foster  HOU   RB   16     0   0    0   1616    16   66
# 1    2           Michael Vick  PHI   QB   12  3018  21    6    676     9    0
# 2    3          Aaron Rodgers   GB   QB   15  3922  28   11    356     4    0
# 3    4              Tom Brady   NE   QB   16  3900  36    4     30     1    0
# 4    5         Peyton Manning  IND   QB   16  4700  33   17     18     0    0
# 5    6        Philip Rivers Q  LAC   QB   16  4710  30   13     52     0    0
# 6    7          Drew Brees IR   NO   QB   16  4620  33   22     -3     0    1
# 7    8           Josh Freeman   TB   QB   16  3451  25    6    364     0    0
# 8    9              Matt Ryan  ATL   QB   16  3705  28    9    122     0    0
# 9   10            Matt Schaub  HOU   QB   16  4369  24   12     28     0    0
# 10  11        Adrian Peterson  MIN   RB   15     0   0    0   1298    12   36
# ...

# %%
fantasystats_2011_df = pd.read_csv("../data/fantasystats_2011.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2010_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2011_df
# Out:
#     RK                  NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1         Aaron Rodgers   GB   QB   15  4637  45    6    257     3    0
# 1    2         Drew Brees IR   NO   QB   16  5476  46   14     86     1    0
# 2    3            Cam Newton  CAR   QB   16  4051  21   17    709    14    1
# 3    4             Tom Brady   NE   QB   16  5235  39   12    109     3    0
# 4    5      Matthew Stafford  DET   QB   16  5038  41   16     78     0    0
# 5    6              Ray Rice  BAL   RB   16     1   1    0   1362    12   76
# 6    7          LeSean McCoy  PHI   RB   15     0   0    0   1309    17   48
# 7    8           Eli Manning  NYG   QB   16  4910  29   16     15     1    0
# 8    9             Tony Romo  DAL   QB   16  4184  31   10     46     1    0
# 9   10             Matt Ryan  ATL   QB   16  4177  29   12     84     2    0
# 10  11        Calvin Johnson  DET   WR   16     0   0    0     11     0   96
# ...

# %%
fantasystats_2012_df = pd.read_csv("../data/fantasystats_2012.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2012_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2012_df
# Out:
#     RK                   NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1          Drew Brees IR   NO   QB   16  5177  43   19      5     1    0
# 1    2          Aaron Rodgers   GB   QB   16  4295  39    8    259     2    1
# 2    3              Tom Brady   NE   QB   16  4827  34    8     32     4    0
# 3    4             Cam Newton  CAR   QB   16  3869  19   12    741     8    0
# 4    5  Robert Griffin III IR  WAS   QB   15  3200  20    5    815     7    0
# 5    6         Peyton Manning  DEN   QB   16  4659  37   11      6     0    0
# 6    7        Adrian Peterson  MIN   RB   16     0   0    0   2097    12   40
# 7    8              Matt Ryan  ATL   QB   16  4719  32   14    141     1    0
# 8    9              Tony Romo  DAL   QB   16  4903  28   19     49     1    1
# 9   10            Andrew Luck  IND   QB   16  4374  23   18    255     5    0
# 10  11         Russell Wilson  SEA   QB   16  3118  26   10    489     4    0
# ...

# %%
fantasystats_2013_df = pd.read_csv("../data/fantasystats_2013.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2013_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2013_df
# Out:
#     RK                   NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1         Peyton Manning  DEN   QB   16  5477  55   10    -31     1    0
# 1    2          Drew Brees IR   NO   QB   16  5162  39   12     52     3    0
# 2    3         Jamaal Charles   KC   RB   15     0   0    0   1287    12   70
# 3    4             Cam Newton  CAR   QB   16  3379  24   13    585     6    0
# 4    5            Andrew Luck  IND   QB   16  3822  23    9    377     4    0
# 5    6            Andy Dalton  CIN   QB   16  4296  33   20    183     2    0
# 6    7          Philip Rivers  LAC   QB   16  4478  32   11     72     0    0
# 7    8       Matthew Stafford  DET   QB   16  4650  29   19     74     2    0
# 8    9           LeSean McCoy  PHI   RB   16     0   0    0   1607     9   52
# 9   10         Russell Wilson  SEA   QB   16  3357  26    9    539     1    0
# 10  11       Colin Kaepernick   SF   QB   16  3197  21    8    524     4    0
# ...

# %%
fantasystats_2014_df = pd.read_csv("../data/fantasystats_2014.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2014_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2014_df
# Out:
#     RK                  NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1         Aaron Rodgers   GB   QB   16  4381  38    5    269     2    0
# 1    2           Andrew Luck  IND   QB   16  4761  40   16    263     3    0
# 2    3        Russell Wilson  SEA   QB   16  3475  20    7    849     6    1
# 3    4        Peyton Manning  DEN   QB   16  4727  39   15    -24     0    0
# 4    5  Ben Roethlisberger P  PIT   QB   16  4952  32    9     27     0    0
# 5    6         Drew Brees IR   NO   QB   16  4952  33   17     68     1    1
# 6    7        DeMarco Murray  DAL   RB   16     0   0    0   1845    13   57
# 7    8          Le'Veon Bell  PIT   RB   16     0   0    0   1361     8   83
# 8    9             Matt Ryan  ATL   QB   16  4694  28   14    145     0    0
# 9   10        Ryan Tannehill  MIA   QB   16  4045  27   12    311     1    1
# 10  11             Tom Brady   NE   QB   16  4109  33    9     57     0    0
# ...

# %%
fantasystats_2015_df = pd.read_csv("../data/fantasystats_2015.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2015_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2015_df
# Out:
#     RK                  NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1            Cam Newton  CAR   QB   16  3837  35   10    636    10    0
# 1    2             Tom Brady   NE   QB   16  4770  36    7     53     3    1
# 2    3        Russell Wilson  SEA   QB   16  4024  34    8    553     1    0
# 3    4         Blake Bortles  JAX   QB   16  4428  35   18    310     2    0
# 4    5         Carson Palmer  ARI   QB   16  4671  35   11     24     1    0
# 5    6         Drew Brees IR   NO   QB   15  4870  32   11     14     1    0
# 6    7         Aaron Rodgers   GB   QB   16  3821  31    8    344     1    0
# 7    8          Kirk Cousins  WAS   QB   16  4166  29   11     48     5    0
# 8    9      Matthew Stafford  DET   QB   16  4262  32   13    159     1    1
# 9   10           Eli Manning  NYG   QB   16  4432  35   14     70     0    0
# 10  11      Ryan Fitzpatrick  NYJ   QB   16  3905  31   15    270     2    0
# ...

# %%
fantasystats_2016_df = pd.read_csv("../data/fantasystats_2016.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2016_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2016_df
# Out:
#     RK                  NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1         Aaron Rodgers   GB   QB   16  4428  40    7    369     4    0
# 1    2             Matt Ryan  ATL   QB   16  4944  38    7    117     0    0
# 2    3         Drew Brees IR   NO   QB   16  5208  37   15     20     2    0
# 3    4         David Johnson  ARI   RB   16     0   0    0   1239    16   80
# 4    5           Andrew Luck  IND   QB   15  4240  31   13    341     2    0
# 5    6          Kirk Cousins  WAS   QB   16  4917  25   12     96     4    0
# 6    7       Ezekiel Elliott  DAL   RB   15     0   0    0   1631    15   32
# 7    8       Dak Prescott IR  DAL   QB   16  3667  23    4    282     6    0
# 8    9      Matthew Stafford  DET   QB   16  4327  24   10    207     2    0
# 9   10          Tyrod Taylor  BUF   QB   15  3023  17    6    580     6    0
# 10  11         Blake Bortles  JAX   QB   16  3905  23   16    359     3    1
# ...

# %%
fantasystats_2017_df = pd.read_csv("../data/fantasystats_2017.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2017_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2017_df
# Out:
#     RK                  NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1        Russell Wilson  SEA   QB   16  3983  34   11    586     3    0
# 1    2        Todd Gurley II  LAR   RB   15     0   0    0   1305    13   64
# 2    3            Cam Newton  CAR   QB   16  3302  22   16    754     6    0
# 3    4             Tom Brady   NE   QB   16  4577  32    8     28     0    0
# 4    5            Alex Smith   KC   QB   15  4042  26    5    355     1    0
# 5    6          Carson Wentz  PHI   QB   13  3296  33    7    299     0    0
# 6    7          Kirk Cousins  WAS   QB   16  4093  27   13    179     4    0
# 7    8      Matthew Stafford  DET   QB   16  4446  29   10     98     0    0
# 8    9         Philip Rivers  LAC   QB   16  4515  28   10     -2     0    0
# 9   10         Drew Brees IR   NO   QB   16  4334  23    8     12     2    0
# 10  11  Ben Roethlisberger P  PIT   QB   15  4251  28   14     47     0    0
# ...

# %%
fantasystats_2018_df = pd.read_csv("../data/fantasystats_2018.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2018_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2018_df
# Out:
#     RK                   NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1        Patrick Mahomes   KC   QB   16  5097  50   12    272     2    0
# 1    2              Matt Ryan  ATL   QB   16  4924  35    7    125     3    1
# 2    3   Ben Roethlisberger P  PIT   QB   16  5129  34   16     98     3    1
# 3    4         Deshaun Watson  HOU   QB   16  4165  26    9    551     5    0
# 4    5            Andrew Luck  IND   QB   16  4593  39   15    148     0    1
# 5    6         Todd Gurley II  LAR   RB   14     0   0    0   1251    17   59
# 6    7          Aaron Rodgers   GB   QB   16  4442  25    2    269     2    0
# 7    8             Jared Goff  LAR   QB   16  4688  32   12    108     2    0
# 8    9          Drew Brees IR   NO   QB   15  3992  32    5     22     4    1
# 9   10         Russell Wilson  SEA   QB   16  3448  35    7    376     0    1
# 10  11      Saquon Barkley IR  NYG   RB   16     0   0    0   1307    11   91
# ...

# %%
fantasystats_2019_df = pd.read_csv("../data/fantasystats_2019.csv", skiprows=1 , nrows=50)

# %%
fantasystats_2019_df.shape
# Out:
# (50, 19)

# %%
fantasystats_2019_df
# Out:
#     RK                   NAME TEAM  POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 0    1          Lamar Jackson  BAL   QB   15  3127  36    6   1206     7    0
# 1    2  Christian McCaffrey Q  CAR   RB   16     0   0    0   1387    15  116
# 2    3        Dak Prescott IR  DAL   QB   16  4902  30   11    277     3    0
# 3    4         Russell Wilson  SEA   QB   16  4110  31    5    342     3    0
# 4    5         Deshaun Watson  HOU   QB   15  3852  26   12    413     7    1
# 5    6         Jameis Winston   TB   QB   16  5109  33   30    250     1    0
# 6    7             Josh Allen  BUF   QB   16  3089  20    9    510     9    0
# 7    8        Patrick Mahomes   KC   QB   14  4031  26    5    218     2    0
# 8    9           Kyler Murray  ARI   QB   16  3722  20   12    544     4    0
# 9   10          Aaron Rodgers   GB   QB   16  4002  26    4    183     1    0
# 10  11          Derrick Henry  TEN   RB   15     0   0    0   1540    16   18
# ...

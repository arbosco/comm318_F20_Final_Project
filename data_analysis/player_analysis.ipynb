# %% [markdown]
# This Notebook:
# * Further analysis using the 3 data frames: Fantasy Football stats, League MVPs, and SuperBowl data.
# * A continuation of 'cleaned_initial_data_exploration_1"
# * Uploads & imports a new data frame of the Top-20 player salaries in the NFL(2020).

# %% [markdown]
# #### Load in data analysis notebook for pointer:

# %%
# %run cleaned_initial_data_exploration_1.ipynb
# Out:
#    RK             NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 0   1     Arian Foster  HOU  RB   16     0   0    0   1616    16   66    604
# 1   2     Michael Vick  PHI  QB   12  3018  21    6    676     9    0      0
# 2   3    Aaron Rodgers   GB  QB   15  3922  28   11    356     4    0      0
# 3   4        Tom Brady   NE  QB   16  3900  36    4     30     1    0      0
# 4   5   Peyton Manning  IND  QB   16  4700  33   17     18     0    0      0
# 5   6  Philip Rivers Q  LAC  QB   16  4710  30   13     52     0    0      0
# 6   7    Drew Brees IR   NO  QB   16  4620  33   22     -3     0    1      7
# 7   8     Josh Freeman   TB  QB   16  3451  25    6    364     0    0      0
# 8   9        Matt Ryan  ATL  QB   16  3705  28    9    122     0    0      0
# 9  10      Matt Schaub  HOU  QB   16  4369  24   12     28     0    0      0
#
#    TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS
# 0     2    0      0   1   0    20.4  326.00
# ...

# %% [markdown]
# ## Player analysis:
# - analysis of the players who have appeared most frequently over the past 10 years in the Top-50 and then go into deeper analysis of the players who have appeared most in the Top-10.

# %%
fantasystats_df['NAME']=fantasystats_df['NAME'].str.replace('\xa0.*','')

# %%
#find the repeition of players in the Top-50
# use combined data frame 'fantasystats_df'
fantasystats_df['NAME'].value_counts().head(20)
# Out:
# Matt Ryan             10
# Philip Rivers         10
# Drew Brees            10
# Tom Brady             10
# Ben Roethlisberger     9
# Aaron Rodgers          8
# Cam Newton             8
# Matthew Stafford       8
# Russell Wilson         8
# Eli Manning            8
# Andy Dalton            8
# Joe Flacco             7
# Derek Carr             6
# Antonio Brown          6
# Ryan Tannehill         6
# Alex Smith             6
# Ryan Fitzpatrick       6
# Julio Jones            5
# Carson Palmer          5
# Kirk Cousins           5
# Name: NAME, dtype: int64

# %%
#clean this using pandas 
pd.DataFrame(fantasystats_df['NAME'].value_counts().head(20))
# Out:
#                     NAME
# Matt Ryan             10
# Philip Rivers         10
# Drew Brees            10
# Tom Brady             10
# Ben Roethlisberger     9
# Aaron Rodgers          8
# Cam Newton             8
# Matthew Stafford       8
# Russell Wilson         8
# Eli Manning            8
# Andy Dalton            8
# Joe Flacco             7
# Derek Carr             6
# Antonio Brown          6
# Ryan Tannehill         6
# Alex Smith             6
# Ryan Fitzpatrick       6
# Julio Jones            5
# Carson Palmer          5
# Kirk Cousins           5

# %% [markdown]
# # Analysis of the 5 players who appeared the most:
# 1. Matt Ryan (10)
# 2. Tom Brady (10)
# 3. Drew Brees (10)
# 4. Philip Rivers (9)
# 5. Russell Wilson (8),
#      Eli Manning (8),
#      Ben Roethlisberger (8),
#      Matthew Stafford (8),
#      Andy Dalton (8),
#      Aaron Rodgers (8),
#      Cam Newton (8)

# %%
# find the rows that contain the name 'Matt Ryan'
fantasystats_df[(fantasystats_df['NAME'] == 'Matt Ryan')]
# Out:
#     RK       NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  TD.2  \
# 8    9  Matt Ryan  ATL  QB   16  3705  28    9    122     0    0      0     0
# 9   10  Matt Ryan  ATL  QB   16  4177  29   12     84     2    0      0     0
# 7    8  Matt Ryan  ATL  QB   16  4719  32   14    141     1    0      0     0
# 17  18  Matt Ryan  ATL  QB   16  4515  26   17     55     0    0      0     0
# 8    9  Matt Ryan  ATL  QB   16  4694  28   14    145     0    0      0     0
# 21  22  Matt Ryan  ATL  QB   16  4591  21   16     63     0    0      0     0
# 1    2  Matt Ryan  ATL  QB   16  4944  38    7    117     0    0      0     0
# 19  20  Matt Ryan  ATL  QB   16  4095  20   12    143     0    0      0     0
# 1    2  Matt Ryan  ATL  QB   16  4924  35    7    125     3    1      5     1
# 12  13  Matt Ryan  ATL  QB   15  4466  26   14    147     1    0      0     0
#
#     SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 8   0.0      0   0   0    15.8  252.40  2010
# ...

# %% [markdown]
# ### Analysis
# #### Matt Ryan:
#     This tells me a lot about Matt Ryan's Top-50 fantasy football performances in the past 10 years.
#     * in 2010 he was ranked 9th overall
#     * in 2011 he was ranked 10th overall
#     * in 2012 he was ranked 8th overall
#     * in 2013 he was ranked 18th overall
#     * in 2014 he was ranked 9th overall
#     * in 2015 he was ranked 22nd overall
#     * in 2016 he was ranked 2nd overall
#     * in 2017 he was ranked 20th overall
#     * in 2018 he was ranked 2nd overall
#     * in 2019 he was ranked 13th overall
#
# * he recorded his most amount of fantasy points in a season during the 2018 regular season. He scored 353.96 and was ranked 2nd overall.
# * his position = QB
#
# * he was never the #1 ranked player -- was the player that most consistently appeared within the Top-50 yet was never the #1 point scorer.

# %%
# find the rows that contain the name 'Tom Brady'
fantasystats_df[(fantasystats_df['NAME'] == 'Tom Brady')]
# Out:
#     RK       NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  TD.2  \
# 3    4  Tom Brady   NE  QB   16  3900  36    4     30     1    0      0     0
# 3    4  Tom Brady   NE  QB   16  5235  39   12    109     3    0      0     0
# 2    3  Tom Brady   NE  QB   16  4827  34    8     32     4    0      0     0
# 16  17  Tom Brady   NE  QB   16  4343  25   11     18     0    0      0     0
# 10  11  Tom Brady   NE  QB   16  4109  33    9     57     0    0      0     0
# 1    2  Tom Brady   NE  QB   16  4770  36    7     53     3    1     36     0
# 16  17  Tom Brady   NE  QB   12  3554  28    2     64     0    0      0     0
# 3    4  Tom Brady   NE  QB   16  4577  32    8     28     0    0      0     0
# 15  16  Tom Brady   NE  QB   16  4355  29   11     35     2    1      6     0
# 14  15  Tom Brady   NE  QB   16  4057  24    8     34     3    0      0     0
#
#     SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 3   0.0      0   0   0    18.7  299.00  2010
# ...

# %% [markdown]
# ### Analysis
# #### Tom Brady:
#     This tells me a lot about Tom Brady's Top-50 fantasy football performances in the past 10 years.
#     * in 2010 he was ranked 4th overall
#     * in 2011 he was ranked 4th overall
#     * in 2012 he was ranked 3rd overall
#     * in 2013 he was ranked 17th overall
#     * in 2014 he was ranked 11th overall
#     * in 2015 he was ranked 2nd overall
#     * in 2016 he was ranked 17th overall
#     * in 2017 he was ranked 4th overall
#     * in 2018 he was ranked 16th overall
#     * in 2019 he was ranked 15th overall
#
# * He scored his most points in 2011 where he was ranked 4th overall.
#     * this is interesting because even in 2015 when he was the 2nd ranked player overall he only generated 343.70 points.
#
# * he was never the #1 ranked player over the past 10 seasons
#
# * his position = QB

# %%
#find the rows that contain the name 'Drew Brees'
fantasystats_df[(fantasystats_df['NAME'] == 'Drew Brees')]
# Out:
#     RK        NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 6    7  Drew Brees   NO  QB   16  4620  33   22     -3     0    1      7
# 1    2  Drew Brees   NO  QB   16  5476  46   14     86     1    0      0
# 0    1  Drew Brees   NO  QB   16  5177  43   19      5     1    0      0
# 1    2  Drew Brees   NO  QB   16  5162  39   12     52     3    0      0
# 5    6  Drew Brees   NO  QB   16  4952  33   17     68     1    1      1
# 5    6  Drew Brees   NO  QB   15  4870  32   11     14     1    0      0
# 2    3  Drew Brees   NO  QB   16  5208  37   15     20     2    0      0
# 9   10  Drew Brees   NO  QB   16  4334  23    8     12     2    0      0
# 8    9  Drew Brees   NO  QB   15  3992  32    5     22     4    1      1
# 26  27  Drew Brees   NO  QB   11  2979  27    4     -4     1    0      0
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 6      0  0.0      0   0   0    16.8  269.20  2010
# 1      0  0.0      0   0   0    24.5  391.64  2011
# ...

# %% [markdown]
# ### Analysis
# #### Drew Brees:
# * ### Analysis
# #### Tom Brady:
#     This tells me a lot about Drew Brees's Top-50 fantasy football performances in the past 10 years.
#     * in 2010 he was ranked 7th overall
#     * in 2011 he was ranked 2nd overall
#     * in 2012 he was ranked 1st overall
#     * in 2013 he was ranked 2nd overall
#     * in 2014 he was ranked 6th overall
#     * in 2015 he was ranked 6th overall
#     * in 2016 he was ranked 3rd overall
#     * in 2017 he was ranked 10th overall
#     * in 2018 he was ranked 9th overall
#     * in 2019 he was ranked 27th overall
#
# * He scored his most points in 2011 where he was ranked 2th overall.
#     * this is interesting because even in 2012 when he was the 1st ranked player overall he generated less points than when he was the 2nd ranked player.
#
# * he was the #1 ranked player once
#
# * his position = QB

# %%
fantasystats_df[(fantasystats_df['NAME'] == 'Philip Rivers')]
# Out:
#     RK           NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 5    6  Philip Rivers  LAC  QB   16  4710  30   13     52     0    0      0
# 12  13  Philip Rivers  LAC  QB   16  4624  27   20     36     1    0      0
# 31  32  Philip Rivers  LAC  QB   16  3606  26   15     40     0    0      0
# 6    7  Philip Rivers  LAC  QB   16  4478  32   11     72     0    0     -9
# 14  15  Philip Rivers  LAC  QB   16  4286  31   18    104     0    0      0
# 11  12  Philip Rivers  LAC  QB   16  4792  29   13     28     0    0      0
# 15  16  Philip Rivers  LAC  QB   16  4386  33   21     35     0    0      0
# 8    9  Philip Rivers  LAC  QB   16  4515  28   10     -2     0    0      0
# 12  13  Philip Rivers  LAC  QB   16  4308  32   12      7     0    0      0
# 22  23  Philip Rivers  LAC  QB   16  4615  23   20     29     0    0      0
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 5      0  0.0      0   0   0    17.6  281.60  2010
# ...

# %% [markdown]
# ### Analysis
# #### Philip Rivers :
#     This tells me a lot about Matt Ryan's Top-50 fantasy football performances in the past 10 years.
#     * in 2010 he DID NOT APPEAR ON THE TOP-50 LIST
#     * in 2011 he was ranked 13th overall
#     * in 2012 he was ranked 32nd overall
#     * in 2013 he was ranked 7th overall
#     * in 2014 he was ranked 15th overall
#     * in 2015 he was ranked 12th overall
#     * in 2016 he was ranked 16th overall
#     * in 2017 he was ranked 9th overall
#     * in 2018 he was ranked 13th overall
#     * in 2019 he was ranked 23rd overall
#
# * He scored his most amount of points in 2013 where he was the 7th ranked player overall
#
# * He never broke 300 total points during any season in the past 10 years
#
# * His position = QB

# %% [markdown]
# ### Shorter Analysis of the players who have appeared 5-11 on this list (all appearing in 8 out of the past 10 Top-50 lists):

# %%
#find the rows that contain the name 'Russell Wilson'
fantasystats_df[(fantasystats_df['NAME'] == 'Russell Wilson')]
# Out:
#     RK            NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 10  11  Russell Wilson  SEA  QB   16  3118  26   10    489     4    0      0
# 9   10  Russell Wilson  SEA  QB   16  3357  26    9    539     1    0      0
# 2    3  Russell Wilson  SEA  QB   16  3475  20    7    849     6    1     17
# 2    3  Russell Wilson  SEA  QB   16  4024  34    8    553     1    0      0
# 12  13  Russell Wilson  SEA  QB   16  4219  21   11    259     1    2     14
# 0    1  Russell Wilson  SEA  QB   16  3983  34   11    586     3    0      0
# 9   10  Russell Wilson  SEA  QB   16  3448  35    7    376     0    1    -11
# 3    4  Russell Wilson  SEA  QB   16  4110  31    5    342     3    0      0
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 10     0  0.0      0   0   0    17.2  275.62  2012
# 9      0  0.0      0   0   1    16.9  270.18  2013
# 2      0  0.0      0   0   0    20.5  327.60  2014
# 2      0  0.0      0   0   0    21.0  336.26  2015
# ...

# %% [markdown]
# #### Analysis: Russell Wilson
# * Russell Wilson was ranked #1 once
# * He was ranked in the top-3 3 out of the past 10 years

# %%
# find the rows that contain the name 'Eli Manning'
fantasystats_df[(fantasystats_df['NAME'] == 'Eli Manning')]
# Out:
#     RK         NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 14  15  Eli Manning  NYG  QB   16  4002  31   25     70     0    0      0
# 7    8  Eli Manning  NYG  QB   16  4910  29   16     15     1    0      0
# 20  21  Eli Manning  NYG  QB   16  3948  26   15     30     0    0      0
# 12  13  Eli Manning  NYG  QB   16  4410  30   14     31     1    0      0
# 9   10  Eli Manning  NYG  QB   16  4432  35   14     70     0    0      0
# 27  28  Eli Manning  NYG  QB   16  4027  26   16     -9     0    0      0
# 33  34  Eli Manning  NYG  QB   15  3468  19   13     26     1    0      0
# 22  23  Eli Manning  NYG  QB   16  4299  21   11     20     1    0      0
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 14     0  0.0      0   0   0    14.4  231.08  2010
# 7      0  0.0      0   0   0    17.5  279.90  2011
# 20     0  0.0      0   0   0    14.6  232.92  2012
# 12     0  0.0      0   0   0    16.8  269.50  2014
# ...

# %% [markdown]
# #### Analysis: Eli Manning
# * Was never ranked #1
# * Was ranked in the top-10 twice in the past 10 years

# %%
# find the rows that contain the name 'Ben Roethlisberger'
fantasystats_df[(fantasystats_df['NAME'] == 'Ben Roethlisberger')]
# Out:
#     RK                NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 25  26  Ben Roethlisberger  PIT  QB   12  3200  17    5    176     2    0
# 19  20  Ben Roethlisberger  PIT  QB   15  4077  21   14     70     0    0
# 23  24  Ben Roethlisberger  PIT  QB   13  3265  26    8     92     0    0
# 13  14  Ben Roethlisberger  PIT  QB   16  4261  28   14     99     1    0
# 4    5  Ben Roethlisberger  PIT  QB   16  4952  32    9     27     0    0
# 24  25  Ben Roethlisberger  PIT  QB   12  3938  21   16     29     0    0
# 19  20  Ben Roethlisberger  PIT  QB   14  3819  29   13     14     1    0
# 10  11  Ben Roethlisberger  PIT  QB   15  4251  28   14     47     0    0
# 2    3  Ben Roethlisberger  PIT  QB   16  5129  34   16     98     3    1
#
#     YDS.2  TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 25      0     0  0.0      0   0   0    17.6  211.60  2010
# 19      0     0  0.0      0   0   0    14.4  216.08  2011
# ...

# %% [markdown]
# #### Analysis: Ben Roethlisberger
# * Was never ranked #1
# * Appeared in the top-10 twice

# %%
# find the rows that contain the name 'Matthew Stafford'
fantasystats_df[(fantasystats_df['NAME'] == 'Matthew Stafford')]
# Out:
#     RK              NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  \
# 4    5  Matthew Stafford  DET  QB   16  5038  41   16     78     0    0
# 11  12  Matthew Stafford  DET  QB   16  4967  20   17    126     4    1
# 7    8  Matthew Stafford  DET  QB   16  4650  29   19     74     2    0
# 19  20  Matthew Stafford  DET  QB   16  4257  22   12     93     2    0
# 8    9  Matthew Stafford  DET  QB   16  4262  32   13    159     1    1
# 8    9  Matthew Stafford  DET  QB   16  4327  24   10    207     2    0
# 7    8  Matthew Stafford  DET  QB   16  4446  29   10     98     0    0
# 32  33  Matthew Stafford  DET  QB   16  3777  21   11     71     0    0
#
#     YDS.2  TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 4       0     0  0.0      0   0   0    21.5  343.32  2011
# 11      3     0  0.0      0   0   0    17.2  275.58  2012
# 7       0     0  0.0      0   0   0    17.5  279.40  2013
# 19      0     0  0.0      0   0   0    15.7  251.58  2014
# ...

# %% [markdown]
# #### Analysis: Matthew Stafford
# * was never the #1 rank
# * but has appeared in the top-10 five out of the past ten years

# %%
# find the rows that contain the name 'Andy Dalton'
fantasystats_df[(fantasystats_df['NAME'] == 'Andy Dalton')]
# Out:
#     RK         NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 24  25  Andy Dalton  CIN  QB   16  3398  20   13    152     1    0      0
# 14  15  Andy Dalton  CIN  QB   16  3669  27   16    120     4    0      0
# 5    6  Andy Dalton  CIN  QB   16  4296  33   20    183     2    0      0
# 28  29  Andy Dalton  CIN  QB   16  3398  19   17    169     4    1     18
# 19  20  Andy Dalton  CIN  QB   13  3250  25    7    142     3    0      0
# 13  14  Andy Dalton  CIN  QB   16  4206  18    8    184     4    0      0
# 23  24  Andy Dalton  CIN  QB   16  3320  25   12     99     0    0      0
# 35  36  Andy Dalton  CIN  QB   13  3494  16   14     73     4    1     -4
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 24     0  0.0      0   0   0    12.9  207.12  2011
# 14     0  0.0      0   0   0    15.7  250.76  2012
# 5      0  0.0      0   0   0    18.0  288.14  2013
# 28     1  0.0      0   0   0    14.0  224.62  2014
# ...

# %% [markdown]
# #### Analysis: Andy Dalton
# * Was never the #1 rank
# * appeared in the top-10 once

# %%
# find the rows that contain the name 'Aaron Rodgers'
fantasystats_df[(fantasystats_df['NAME'] == 'Aaron Rodgers')]
# Out:
#    RK           NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 2   3  Aaron Rodgers   GB  QB   15  3922  28   11    356     4    0      0
# 0   1  Aaron Rodgers   GB  QB   15  4637  45    6    257     3    0      0
# 1   2  Aaron Rodgers   GB  QB   16  4295  39    8    259     2    1     -1
# 0   1  Aaron Rodgers   GB  QB   16  4381  38    5    269     2    0      0
# 6   7  Aaron Rodgers   GB  QB   16  3821  31    8    344     1    0      0
# 0   1  Aaron Rodgers   GB  QB   16  4428  40    7    369     4    0      0
# 6   7  Aaron Rodgers   GB  QB   16  4442  25    2    269     2    0      0
# 9  10  Aaron Rodgers   GB  QB   16  4002  26    4    183     1    0      0
#
#    TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 2     0  0.0      0   0   0    20.3  304.48  2010
# 0     0  0.0      0   0   0    26.5  397.18  2011
# 1     0  0.0      0   0   0    21.5  343.60  2012
# 0     0  0.0      0   0   0    22.1  354.14  2014
# ...

# %% [markdown]
# #### Analysis: Aaron Rodgers
# * Was the number 1 player 3 out of the past 10 years
# * has been in the top-10 eight out of the past ten years

# %%
#find the rows that contain the name 'Cam Newton'
fantasystats_df[(fantasystats_df['NAME'] == 'Cam Newton')]
# Out:
#     RK        NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 2    3  Cam Newton  CAR  QB   16  4051  21   17    709    14    1     27
# 3    4  Cam Newton  CAR  QB   16  3869  19   12    741     8    0      6
# 3    4  Cam Newton  CAR  QB   16  3379  24   13    585     6    0      0
# 21  22  Cam Newton  CAR  QB   14  3127  18   12    539     5    0      0
# 0    1  Cam Newton  CAR  QB   16  3837  35   10    636    10    0      0
# 18  19  Cam Newton  CAR  QB   15  3509  19   14    359     5    0      0
# 2    3  Cam Newton  CAR  QB   16  3302  22   16    754     6    0      0
# 13  14  Cam Newton  CAR  QB   14  3395  24   13    488     4    0      0
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G    FPTS  YEAR
# 2      0  0.0      0   0   0    23.1  369.64  2011
# 3      0  0.0      0   0   0    20.2  323.46  2012
# 3      0  0.0      0   0   0    18.6  297.66  2013
# 21     0  0.0      0   0   0    17.8  248.98  2014
# 0      0  0.0      0   0   0    24.3  389.08  2015
# ...

# %% [markdown]
# #### Analysis: Cam Newton
# * Has been the #1 player once
# * Has been ranked in the top-10 five out of the past ten years

# %% [markdown]
# # Analysis of player salaries
# 1. Import the .csv file 'player_salaries'
# 2. Analyze who is on the list and if any of them are also on the list of players above (most re-occurring players)
# 3. What is the positional breakdown of the most paid players in the league
# 4. Find correlation with their fantasy rankings --

# %%
# give it the pointer 'player_salaries'

player_salaries = pd.read_csv('../data/Player_Salaries.csv')

# %%
player_salaries.to_csv('../data/Player_Salaries.csv', index=False)

# %% [markdown]
# #### Create numeric version of `AVG_SALARY`
#
# 1. strip out `$` and `,` characters
# 2. convert `str` type to an integer

# %%
player_salaries['AVG_SALARY_num']=player_salaries['AVG SALARY'].str.replace('[$,]','').astype(int)

# %%
player_salaries
# Out:
#     RK              PLAYER POS   AVG SALARY  AVG_SALARY_num
# 0    1     Patrick Mahomes  QB  $45,000,000        45000000
# 1    2      Deshaun Watson  QB  $39,000,000        39000000
# 2    3      Russell Wilson  QB  $35,000,000        35000000
# 3    4  Ben Roethlisberger  QB  $34,000,000        34000000
# 4    5          Jared Goff  QB  $33,500,000        33500000
# 5    5       Aaron Rodgers  QB  $33,500,000        33500000
# 6    7        Kirk Cousins  QB  $33,000,000        33000000
# 7    8        Carson Wentz  QB  $32,000,000        32000000
# 8    9        Dak Prescott  QB  $31,409,000        31409000
# 9   10           Matt Ryan  QB  $30,000,000        30000000
# 10  11      Ryan Tannehill  QB  $29,500,000        29500000
# 11  12     Jimmy Garoppolo  QB  $27,500,000        27500000
# 12  13     DeAndre Hopkins  WR  $27,250,000        27250000
# 13  14            Joe Bosa  DE  $27,000,000        27000000
# 14  14   Matthew Stafford   QB  $27,000,000        27000000
# ...

# %% [markdown]
# *** this is a list of the Top-20 salaries in the NFL for the 2020 season ***

# %%
#find out who the #1 ranked WR is -- 
# does this match 'DeAndre Hopkins'
fantasystats_2019_df[(fantasystats_2019_df['POS']=='WR')]
# Out:
#     RK              NAME TEAM POS  GMS  YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 25  26    Michael Thomas   NO  WR   16    0   0    0     -9     0  149   1725
# 40  41      Chris Godwin   TB  WR   14    0   0    0      8     0   86   1333
# 46  47  Kenny Golladay Q  DET  WR   16    0   0    0      0     0   65   1190
# 49  50       Cooper Kupp  LAR  WR   16    0   0    0      4     0   94   1161
#
#     TD.2  SCK  INT.1  FF  FR  FPTS/G   FPTS  YEAR
# 25     9  0.0      0   0   0    14.1  225.6  2019
# 40     9  0.0      0   0   0    13.6  190.1  2019
# 46    11  0.0      0   0   0    11.4  183.0  2019
# 49    10  0.0      0   0   0    11.0  176.5  2019

# %%
fantasystats_df_Top10
# Out:
#     RK             NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 0    1     Arian Foster  HOU  RB   16     0   0    0   1616    16   66    604
# 1    2     Michael Vick  PHI  QB   12  3018  21    6    676     9    0      0
# 2    3    Aaron Rodgers   GB  QB   15  3922  28   11    356     4    0      0
# 3    4        Tom Brady   NE  QB   16  3900  36    4     30     1    0      0
# 4    5   Peyton Manning  IND  QB   16  4700  33   17     18     0    0      0
# ..  ..              ...  ...  ..  ...   ...  ..  ...    ...   ...  ...    ...
# 5    6   Jameis Winston   TB  QB   16  5109  33   30    250     1    0      0
# 6    7       Josh Allen  BUF  QB   16  3089  20    9    510     9    0      0
# 7    8  Patrick Mahomes   KC  QB   14  4031  26    5    218     2    0      0
# 8    9     Kyler Murray  ARI  QB   16  3722  20   12    544     4    0      0
# 9   10    Aaron Rodgers   GB  QB   16  4002  26    4    183     1    0      0
#
# ...

# %% [markdown]
# #### initial analysis:
# - every single player on this Top-20 list is a Quarterback
# - #1 is Patrick Mahomes (who has appeared as both the #1 rank and the League MVP in 2018)

# %% [markdown]
# ### Players who have appeared the most in the Top-50 ranks:
#
# 1. Matt Ryan (10)
# 2. Tom Brady (10)
# 3. Drew Brees (10)
# 4. Philip Rivers (10)
# 5. Russell Wilson (8),
#      Eli Manning (8),
#      Ben Roethlisberger (8),
#      Matthew Stafford (8),
#      Andy Dalton (8),
#      Aaron Rodgers (8),
#      Cam Newton (8)

# %% [markdown]
# #### What I am doing in the code below is trying to find out if frequency in appearing in the Top-50 fantasy football ranks correlated with being among the players with the top average salaries in the League.

# %%
#search for the players analyzed above: 
#1. Matt Ryan
player_salaries[(player_salaries['PLAYER'] == 'Matt Ryan')]
# Out:
#    RK     PLAYER POS   AVG SALARY  AVG_SALARY_num
# 9  10  Matt Ryan  QB  $30,000,000        30000000

# %%
#search for the players analyzed above: 
#2. Tom Brady
player_salaries[(player_salaries['PLAYER'] == 'Tom Brady')]
# Out:
#     RK     PLAYER POS   AVG SALARY  AVG_SALARY_num
# 19  16  Tom Brady  QB  $25,000,000        25000000

# %%
#search for the players analyzed above: 
#3. Drew Brees
player_salaries[(player_salaries['PLAYER'] == 'Drew Brees')]
# Out:
#     RK      PLAYER POS   AVG SALARY  AVG_SALARY_num
# 17  16  Drew Brees  QB  $25,000,000        25000000

# %%
#search for the players analyzed above: 
#4. Philip Rivers
player_salaries[(player_salaries['PLAYER'] == 'Philip Rivers')]
# Out:
#     RK         PLAYER POS   AVG SALARY  AVG_SALARY_num
# 18  16  Philip Rivers  QB  $25,000,000        25000000

# %%
#search for the players analyzed above: 
#5. Russell Wilson
player_salaries[(player_salaries['PLAYER'] == 'Russell Wilson')]
# Out:
#    RK          PLAYER POS   AVG SALARY  AVG_SALARY_num
# 2   3  Russell Wilson  QB  $35,000,000        35000000

# %%
#search for the players analyzed above: 
#5. Eli Manning
player_salaries[(player_salaries['PLAYER'] == 'Eli Manning')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %% [markdown]
# *** Eli Manning retired in 2018** -- therefore he would not be on this list

# %%
#search for the players analyzed above: 
#5. Ben Roethlisberger
player_salaries[(player_salaries['PLAYER'] == 'Ben Roethlisberger')]
# Out:
#    RK              PLAYER POS   AVG SALARY  AVG_SALARY_num
# 3   4  Ben Roethlisberger  QB  $34,000,000        34000000

# %%
#search for the players analyzed above: 
#5. Matthew Stafford
player_salaries[(player_salaries['PLAYER'] == 'Matthew Stafford ')]
# Out:
#     RK             PLAYER POS   AVG SALARY  AVG_SALARY_num
# 14  14  Matthew Stafford   QB  $27,000,000        27000000

# %%
#search for the players analyzed above: 
#5. Andy Dalton
player_salaries[(player_salaries['PLAYER'] == 'Andy Dalton ')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %% [markdown]
# #### Andy Dalton not one of the Top-20 paid players in the NFL***

# %%
#search for the players analyzed above: 
#5. Aaron Rodgers
player_salaries[(player_salaries['PLAYER'] == 'Aaron Rodgers')]
# Out:
#    RK         PLAYER POS   AVG SALARY  AVG_SALARY_num
# 5   5  Aaron Rodgers  QB  $33,500,000        33500000

# %%
#search for the players analyzed above: 
#5. Cam Newton 
player_salaries[(player_salaries['PLAYER'] == 'Cam Newton')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %% [markdown]
# #### Cam Newton not one of the Top-20 paid players in the NFL***

# %% [markdown]
# Of the players who appeared 8 or more times in the past 10 years, all but 3 are among the Top-20 highest salaries in the NFL as of 2020. From this information I can infer that generating the most amount of points (fantasy football) correlates to position and also average salary. Many of the top fantasy football players have a few of the same characteristics:
#     - 1. they are Quarterbacks
#     - 2. they have reappeared multiple times in the Top-50 fantasy players list over the past 10 years
#     - 3. They are among the highest paid players in the league

# %% [markdown]
# # Comparing top-salaries in the league with #1 fantasy football ranks:
# - also look into those who have held the #1 spot AND have been deemed league MVP in the past 10 years

# %%
league_MVP_df
# Out:
#    Year   Lg Pos           Player                    Tm
# 0  2019  NFL  QB    Lamar Jackson      Baltimore Ravens
# 1  2018  NFL  QB  Patrick Mahomes    Kansas City Chiefs
# 2  2017  NFL  QB        Tom Brady  New England Patriots
# 3  2016  NFL  QB        Matt Ryan       Atlanta Falcons
# 4  2015  NFL  QB       Cam Newton     Carolina Panthers
# 5  2014  NFL  QB    Aaron Rodgers     Green Bay Packers
# 6  2013  NFL  QB   Peyton Manning        Denver Broncos
# 7  2012  NFL  RB  Adrian Peterson     Minnesota Vikings
# 8  2011  NFL  QB    Aaron Rodgers     Green Bay Packers
# 9  2010  NFL  QB        Tom Brady  New England Patriots

# %%
#search each of these 10 names in the 'player_salaries' data frame
#1. Tom Brady

# %%
player_salaries[(player_salaries['PLAYER'] == 'Tom Brady')]
# Out:
#     RK     PLAYER POS   AVG SALARY  AVG_SALARY_num
# 19  16  Tom Brady  QB  $25,000,000        25000000

# %%
player_salaries[(player_salaries['PLAYER'] == 'Aaron Rodgers')]
# Out:
#    RK         PLAYER POS   AVG SALARY  AVG_SALARY_num
# 5   5  Aaron Rodgers  QB  $33,500,000        33500000

# %%
player_salaries[(player_salaries['PLAYER'] == 'Adrian Peterson')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %%
player_salaries[(player_salaries['PLAYER'] == 'Peyton Manning')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %% [markdown]
# *** Peyton Manning is retired so he would not appear on Top-20 2020 player salaries list ***

# %%
player_salaries[(player_salaries['PLAYER'] == 'Cam Newton')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %%
player_salaries[(player_salaries['PLAYER'] == 'Matt Ryan')]
# Out:
#    RK     PLAYER POS   AVG SALARY  AVG_SALARY_num
# 9  10  Matt Ryan  QB  $30,000,000        30000000

# %%
player_salaries[(player_salaries['PLAYER'] == 'Patrick Mahomes')]
# Out:
#    RK           PLAYER POS   AVG SALARY  AVG_SALARY_num
# 0   1  Patrick Mahomes  QB  $45,000,000        45000000

# %%
player_salaries[(player_salaries['PLAYER'] == 'Lamar Jackson')]
# Out:
# Empty DataFrame
# Columns: [RK, PLAYER, POS, AVG SALARY, AVG_SALARY_num]
# Index: []

# %% [markdown]
# Factors that go into who gets paid the most/things to consider:
# - Lamar Jackson is still in his rookie contract so he hasn't had to negotiate a deal since his breakout season in 2019. I would expect his next contract to be HUGE.

# %% [markdown]
# # Player Salaries Visualizations:

# %%
player_salaries_1=player_salaries[['PLAYER','AVG_SALARY_num']]

player_salaries_1.plot(x='PLAYER', y='AVG_SALARY_num', 
                       kind='barh', figsize=(6,12))
# Out:
# <AxesSubplot:ylabel='PLAYER'>

# %% [markdown]
# This is a horizontal bar chart of the top-20 paid players in the NFL. The bar represents their average salary (as of 2020).

# %%
#use this code to make a bar graph with multiple columns 
# first follow the steps below

# make a list of the columns to use
cols = ['NAME', 'POS', 'FPTS']

# CODE THE BAR CHART BELOW
fantasystats_df_Top1[cols].head()

fantasystats_df_Top1[cols].plot(kind='bar', x='NAME', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='NAME'>

# %% [markdown]
# This bar graph is the Top-1 ranks with the bar representing the total fantasy points they scored in the year they held the #1 ranked spot.

# %%
# create a pointer and point to each row in the Top-10 combined data frame that represents stats for 'Aaron Rodgers'
Aaron_Rodgers_top10 = fantasystats_df_Top10[(fantasystats_df_Top10['NAME'] == 'Aaron Rodgers')]

# %%
#use this code to make a bar graph with all of the occurrences Aaron Rodgers appeared in the Top10
# first follow the steps below

# make a list of the columns to use
# here take three points FPTS, NAME and 
# and the County column
cols = ['FPTS', 'YEAR', 'RK']


Aaron_Rodgers_top10[cols]

Aaron_Rodgers_top10[cols].plot(kind='bar', x='YEAR', figsize=(10,4), title='Aaron Rodgers Total Points vs. Rank')
# Out:
# <AxesSubplot:title={'center':'Aaron Rodgers Total Points vs. Rank'}, xlabel='YEAR'>

# %% [markdown]
# This is a graph of the total fantasy points scored by Aaron Rodgers in each of the past 10 years (blue bar). The orange bar represents his rank in that same year, the lower/smaller the orange bar the higher the rank. No orange bar (years 2014 & 2016) indicates he was no ranked in the top-10 that year.

# %% [markdown]
# #### Analysis of this chart:
# - low ranks are better so the orange indicated that throughout the past 10 years he has been a very highly ranked, high caliber player
# - 2011 was the highest bar indicating he scored the most amount of points in 2011.

# %%
# stripping out extra characters next to some of the names in the 'NAME' column
fantasystats_df_Top10['NAME']=fantasystats_df_Top10['NAME'].str.replace('\xa0.*','')

# %%
fantasystats_df_Top10
# Out:
#     RK             NAME TEAM POS  GMS   YDS  TD  INT  YDS.1  TD.1  REC  YDS.2  \
# 0    1     Arian Foster  HOU  RB   16     0   0    0   1616    16   66    604
# 1    2     Michael Vick  PHI  QB   12  3018  21    6    676     9    0      0
# 2    3    Aaron Rodgers   GB  QB   15  3922  28   11    356     4    0      0
# 3    4        Tom Brady   NE  QB   16  3900  36    4     30     1    0      0
# 4    5   Peyton Manning  IND  QB   16  4700  33   17     18     0    0      0
# ..  ..              ...  ...  ..  ...   ...  ..  ...    ...   ...  ...    ...
# 5    6   Jameis Winston   TB  QB   16  5109  33   30    250     1    0      0
# 6    7       Josh Allen  BUF  QB   16  3089  20    9    510     9    0      0
# 7    8  Patrick Mahomes   KC  QB   14  4031  26    5    218     2    0      0
# 8    9     Kyler Murray  ARI  QB   16  3722  20   12    544     4    0      0
# 9   10    Aaron Rodgers   GB  QB   16  4002  26    4    183     1    0      0
#
# ...

# %%
# how many quarterbacks appear in the top-10 data frame
top10_qb = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='QB')]
len(top10_qb)
# Out:
# 87

# %%
# how many running backs appear in the top-10 data frame

top10_rb = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='RB')]
len(top10_rb)
# Out:
# 13

# %%
# how many wide receivers appear in the top-10 data frame
top10_wr = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='WR')]
len(top10_wr)
# Out:
# 0

# %%
# how many tight ends appear in the top-10 data frame

top10_te = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='TE')]
len(top10_te)
# Out:
# 0

# %%
# how many kickers appear in the top-10 data frame

top10_k = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='K')]
len(top10_k)
# Out:
# 0

# %%
# how many defense/special teams appear in the top-10 data frame

top10_dst = fantasystats_df_Top10[(fantasystats_df_Top10['POS']=='DST')]
len(top10_dst)
# Out:
# 0

# %% [markdown]
# ### New data frame:
# * pos_top10 is a .csv file of the data collected/coded for above. The positional breakdown of the combined Top-10 data frame.

# %%
# load in the 'positional breakdown Top-10.csv'
pos_top10 = pd.read_csv('../data/positional breakdown Top-10.csv')

# %%
# create a bar graph
pos_top10_df=pos_top10[['POS', 'TOTAL']]
pos_top10_df.plot(x='POS', y='TOTAL', kind='bar', figsize=(12,4), title='Positional Breakdown of the Top-10')
# Out:
# <AxesSubplot:title={'center':'Positional Breakdown of the Top-10'}, xlabel='POS'>

# %% [markdown]
# What this notebook tells me for my story:
# - position that dominates the top of the charts
# - correlation between top ranked fantasy players and salary
# - the repeated success of certain players -- something to look at and take risks on

# %% [markdown]
# things to analyze for story:
#
# find current salary, deal and also find their teams success (how they have done past few years)
# create charts/graphs
# need more visualizations
